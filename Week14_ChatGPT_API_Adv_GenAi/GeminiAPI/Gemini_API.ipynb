# %%
from google import genai

client = genai.Client(api_key="AIzaSyCsMjLr0qsYQjIpnp2FY3bsy5TSOAddNbc")

for m in client.models.list():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# ...

# %%
import time
from google import genai
from google.genai import errors

client = genai.Client(api_key="AIzaSyCsMjLr0qsYQjIpnp2FY3bsy5TSOAddNbc")


response = client.models.generate_content(
    model="models/gemini-flash-lite-latest",
    contents="Explain BioBERT in simple words"
)

print(response.text)
# Out:
# Imagine you have a really smart assistant who is excellent at understanding human language. This assistant is called **BERT**.
#
# Now, think of **BioBERT** as that **same smart assistant, but with specialized training to understand medical and biological language.**
#
# Here’s the simple breakdown:
#
# 1. **BERT (The Foundation):** BERT is a huge, powerful computer model trained on massive amounts of general text (like Wikipedia, books, and news). It learns grammar, context, and how words relate to each other in general conversation.
#
# 2. **BioBERT (The Specialist):** Researchers took that smart, general BERT model and gave it *extra homework*. They trained it specifically on huge amounts of **biomedical literature**—things like research papers, clinical notes, and medical journals.
#
# **In super simple terms:**
#
# BioBERT is a **medical expert version of a smart language program.**
#
# ### What does it do?
#
# ...

# %%
chat = client.chats.create(
    model="models/gemini-flash-lite-latest"
)

print(chat.send_message("What is biomedical NLP?").text)
print(chat.send_message("Give one real example").text)
# Out:
# **Biomedical Natural Language Processing (Biomedical NLP)** is a specialized subfield of Natural Language Processing (NLP) that focuses on the application of computational techniques to understand, interpret, and generate **human language specifically found within the biomedical and clinical domains.**
#
# In simpler terms, it's teaching computers to read, understand, and make sense of the massive amounts of text generated in healthcare, life sciences, and medical research.
#
# ---
#
# ## Why is Biomedical NLP Necessary?
#
# The biomedical world is overflowing with unstructured text, which is difficult for traditional databases and statistical analysis to process. This text includes:
#
# 1. **Clinical Notes:** Electronic Health Records (EHRs), physician dictations, discharge summaries, operative reports, and progress notes.
# 2. **Biomedical Literature:** Millions of research articles, abstracts, patents, and clinical trial reports (like those indexed in PubMed/MEDLINE).
# ...

# %% [markdown]
# fastapi
# uvicorn
# google-genai
