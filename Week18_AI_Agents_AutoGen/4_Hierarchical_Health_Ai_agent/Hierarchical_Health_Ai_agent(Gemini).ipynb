# %% [markdown]
# # 🧠 Hierarchical Health Diet Planner AI Agent (Gemini)
# # 👑 Master (Coordinator) → 🥗 Nutritionist → 🩺 Doctor
#
# Scenario
# ==============
# - The user requests a diet plan
# - The master agent understands the health goal
# - The nutritionist designs a suitable meal plan
# - The doctor reviews it for medical safety
# - The master agent provides the final diet plan
#
# Role of Agent
# ==============
# * User – Human input
# * 👑 Master (Diet Manager) – Coordinator
# * 🥗 Nutritionist – Meal expert
# * 🩺 Doctor – Health and safety checker
#
# Message Flow
# ==============
# - User → Master
# - Master → Nutritionist
# - Nutritionist → Master
# - Master → Doctor
# - Doctor → Master
# - Master → User

# %%
# =========================================================
# 1️⃣ IMPORT
# =========================================================
from autogen import ConversableAgent

GEMINI_API_KEY = "Your 🗝 key"

# =========================================================
# 2️⃣ GEMINI LLM CONFIGURATION (PASTE YOUR KEY HERE)
# =========================================================
llm_config = {
    "model": "models/gemini-flash-latest",  # ✅ correct Gemini model
    "api_key": GEMINI_API_KEY,
    "api_type": "google"
}


# =========================================================
# 3️⃣ SUB-AGENT: NUTRITIONIST
# =========================================================
nutritionist = ConversableAgent(
    name="nutritionist",
    system_message=(
        "You are a nutritionist. "
        "Give a short healthy diet plan based on the user's goal."
        "Use simple bullet points only. "
        "No tables. No long explanations."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)


# =========================================================
# 4️⃣ SUB-AGENT: DOCTOR (HEALTH CHECKER)
# =========================================================
doctor = ConversableAgent(
    name="doctor",
    system_message=(
        "You are a doctor. "
        "Briefly check the diet for safety. "
        "Give 3–4 short bullet points. "
        "Add one-line medical disclaimer. "
        "No tables. No long text."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)


# =========================================================
# 5️⃣ MASTER AGENT (COORDINATOR – USER INTERACTIVE)
# =========================================================
master = ConversableAgent(
    name="diet_manager",
    system_message=(
        "You are the master diet planner. "
        "Understand the user's diet goal. "
        "Get a diet plan from the nutritionist. "
        "Get safety feedback from the doctor. "
        "Provide the final approved diet plan. "
        "Use short bullet points only. "
        "No tables. No long explanations."
    ),
    llm_config=llm_config,
    human_input_mode="ALWAYS"   # 👈 User can ask questions
)


# =========================================================
# 6️⃣ USER INPUT (CAN BE CHANGED ANYTIME)
# =========================================================
#user_request = "I want a vegetarian diet plan for weight loss for one day"
user_request = "I want a vegetarian diet plan for weight loss, and I have diabetes."


# =========================================================
# 7️⃣ MASTER → NUTRITIONIST
# =========================================================
nutrition_response = master.initiate_chat(
    recipient=nutritionist,
    message=user_request,
    max_turns=1
).chat_history[-1]["content"]


# =========================================================
# 8️⃣ MASTER → DOCTOR
# =========================================================
doctor_response = master.initiate_chat(
    recipient=doctor,
    message=nutrition_response,
    max_turns=1
).chat_history[-1]["content"]


# =========================================================
# 9️⃣ FINAL OUTPUT TO USER
# =========================================================
print("\n🥗 Diet Plan (Nutritionist):")
print(nutrition_response)

print("\n🩺 Health Review (Doctor):")
print(doctor_response)
# Out:
# diet_manager (to nutritionist):
#
# I want a vegetarian diet plan for weight loss, and I have diabetes.
#
# --------------------------------------------------------------------------------
# nutritionist (to diet_manager):
#
# *   **Prioritize Non-Starchy Vegetables:** Fill half your plate with greens, broccoli, cauliflower, or zucchini at every meal.
# *   **Choose Low Glycemic Carbohydrates:** Select small portions of brown rice, quinoa, barley, or steel-cut oats.
# *   **Boost Plant Protein:** Include lentils, beans, chickpeas, tofu, or Greek yogurt (if dairy is included) in meals for satiety.
# *   **Limit High-Sugar Fruits:** Choose berries, green apples, or citrus fruits in moderation, typically only one serving per day.
# *   **Avoid Refined Carbs:** Eliminate white bread, white pasta, sugary cereals, and sweetened beverages.
# *   **Use Healthy Fats:** Include avocado, nuts, and seeds (like chia or flax) in small, measured quantities.
# *   **Hydration:** Drink plenty of water and unsweetened tea.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ca89c818-7b46-4130-aa02-984d9bb9e8a1): Maximum turns (1) reached
# diet_manager (to doctor):
#
# *   **Prioritize Non-Starchy Vegetables:** Fill half your plate with greens, broccoli, cauliflower, or zucchini at every meal.
# *   **Choose Low Glycemic Carbohydrates:** Select small portions of brown rice, quinoa, barley, or steel-cut oats.
# *   **Boost Plant Protein:** Include lentils, beans, chickpeas, tofu, or Greek yogurt (if dairy is included) in meals for satiety.
# *   **Limit High-Sugar Fruits:** Choose berries, green apples, or citrus fruits in moderation, typically only one serving per day.
# *   **Avoid Refined Carbs:** Eliminate white bread, white pasta, sugary cereals, and sweetened beverages.
# *   **Use Healthy Fats:** Include avocado, nuts, and seeds (like chia or flax) in small, measured quantities.
# *   **Hydration:** Drink plenty of water and unsweetened tea.
#
# --------------------------------------------------------------------------------
# doctor (to diet_manager):
#
# *   The structure is safe, balanced, and nutritionally dense, prioritizing whole, fiber-rich foods.
# *   The plan effectively includes all major macronutrients (complex carbohydrates, healthy fats, and diverse protein sources).
# *   The focus on low glycemic index foods is highly beneficial for stable energy levels and metabolic health.
# *   Ensure adequate iron and Vitamin B12 intake, especially if all dairy products (like Greek yogurt) are minimized or excluded.
#
# ***
#
# *Disclaimer: This general safety review is not a substitute for professional medical advice or personalized nutritional consultation.*
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (037c1012-e723-4038-9887-bf3afd3e4a3b): Maximum turns (1) reached
#
# 🥗 Diet Plan (Nutritionist):
# *   **Prioritize Non-Starchy Vegetables:** Fill half your plate with greens, broccoli, cauliflower, or zucchini at every meal.
# *   **Choose Low Glycemic Carbohydrates:** Select small portions of brown rice, quinoa, barley, or steel-cut oats.
# *   **Boost Plant Protein:** Include lentils, beans, chickpeas, tofu, or Greek yogurt (if dairy is included) in meals for satiety.
# *   **Limit High-Sugar Fruits:** Choose berries, green apples, or citrus fruits in moderation, typically only one serving per day.
# *   **Avoid Refined Carbs:** Eliminate white bread, white pasta, sugary cereals, and sweetened beverages.
# *   **Use Healthy Fats:** Include avocado, nuts, and seeds (like chia or flax) in small, measured quantities.
# *   **Hydration:** Drink plenty of water and unsweetened tea.
#
# 🩺 Health Review (Doctor):
# *   The structure is safe, balanced, and nutritionally dense, prioritizing whole, fiber-rich foods.
# *   The plan effectively includes all major macronutrients (complex carbohydrates, healthy fats, and diverse protein sources).
# *   The focus on low glycemic index foods is highly beneficial for stable energy levels and metabolic health.
# *   Ensure adequate iron and Vitamin B12 intake, especially if all dairy products (like Greek yogurt) are minimized or excluded.
#
# ***
#
# *Disclaimer: This general safety review is not a substitute for professional medical advice or personalized nutritional consultation.*
