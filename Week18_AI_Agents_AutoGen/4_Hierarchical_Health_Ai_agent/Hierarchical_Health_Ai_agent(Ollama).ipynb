# %% [markdown]
# # 🧠 Hierarchical Health Diet Planner AI Agent (Ollama)
# # 👑 Master (Coordinator) → 🥗 Nutritionist → 🩺 Doctor
#
# Scenario
# ==============
# - The user requests a diet plan
# - The master agent understands the health goal
# - The nutritionist designs a suitable meal plan
# - The doctor reviews it for medical safety
# - The master agent provides the final diet plan
#
# Role of Agent
# ==============
# * User – Human input
# * 👑 Master (Diet Manager) – Coordinator
# * 🥗 Nutritionist – Meal expert
# * 🩺 Doctor – Health and safety checker
#
# Message Flow
# ==============
# - User → Master
# - Master → Nutritionist
# - Nutritionist → Master
# - Master → Doctor
# - Doctor → Master
# - Master → User

# %%
# =========================================================
# 1️⃣ IMPORT
# =========================================================
from autogen import ConversableAgent


# =========================================================
# 2️⃣ LLAMA 3.1 8B (OLLAMA) LLM CONFIGURATION
# =========================================================
llm_config = {
    "model": "llama3.1:8b",
    "api_type": "ollama",
    "base_url": "http://localhost:11434/v1",
    "api_key": "ollama"   # dummy value (required by AutoGen)
}


# =========================================================
# 3️⃣ SUB-AGENT: NUTRITIONIST
# =========================================================
nutritionist = ConversableAgent(
    name="nutritionist",
    system_message=(
        "You are a nutritionist. "
        "Give a short healthy diet plan based on the user's goal. "
        "Use simple bullet points only. "
        "No tables. No long explanations."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)


# =========================================================
# 4️⃣ SUB-AGENT: DOCTOR (HEALTH CHECKER)
# =========================================================
doctor = ConversableAgent(
    name="doctor",
    system_message=(
        "You are a doctor. "
        "Briefly check the diet for safety. "
        "Give 3–4 short bullet points. "
        "Add one-line medical disclaimer. "
        "No tables. No long text."
    ),
    llm_config=llm_config,
    human_input_mode="NEVER"
)


# =========================================================
# 5️⃣ MASTER AGENT (COORDINATOR – USER INTERACTIVE)
# =========================================================
master = ConversableAgent(
    name="diet_manager",
    system_message=(
        "You are the master diet planner. "
        "Understand the user's diet goal. "
        "Get a plan from the nutritionist. "
        "Get safety feedback from the doctor. "
        "Provide the final approved diet plan. "
        "Use short bullet points only. "
        "No tables. No long explanations."
    ),
    llm_config=llm_config,
    human_input_mode="ALWAYS"
)


# =========================================================
# 6️⃣ USER INPUT
# =========================================================
user_request = "I want a vegetarian diet plan for weight loss, and I have diabetes."


# =========================================================
# 7️⃣ MASTER → NUTRITIONIST
# =========================================================
nutrition_response = master.initiate_chat(
    recipient=nutritionist,
    message=user_request,
    max_turns=1
).chat_history[-1]["content"]


# =========================================================
# 8️⃣ MASTER → DOCTOR
# =========================================================
doctor_response = master.initiate_chat(
    recipient=doctor,
    message=nutrition_response,
    max_turns=1
).chat_history[-1]["content"]


# =========================================================
# 9️⃣ FINAL OUTPUT TO USER
# =========================================================
print("\n🥗 Diet Plan (Nutritionist):")
print(nutrition_response)

print("\n🩺 Health Review (Doctor):")
print(doctor_response)
# Out:
# diet_manager (to nutritionist):
#
# I want a vegetarian diet plan for weight loss, and I have diabetes.
#
# --------------------------------------------------------------------------------
# nutritionist (to diet_manager):
#
# Here is a 7-day sample vegetarian diet plan for weight loss with diabetes:
#
# * Eat:
# 	+ Leafy greens (spinach, kale, collard greens)
# 	+ Cruciferous vegetables (broccoli, cauliflower, bell peppers)
# 	+ Legumes (lentils, chickpeas, black beans)
# 	+ Whole grains (brown rice, quinoa, whole wheat bread)
# 	+ Nuts and seeds (almonds, chia seeds, flaxseeds)
# * Include:
# 	+ 1-2 cups of non-starchy vegetables per meal
# 	+ 1/2 cup of legumes or lentils per serving
# 	+ 1 tablespoon of healthy oil per day
# * Limit:
# 	+ Sugary drinks and desserts
# 	+ Refined grains (white rice, white bread)
# 	+ High-fat foods (cheese, butter)
# * Choose:
# 	+ Low-carb vegetables like tomatoes and cucumbers for snacks
# 	+ Herbs and spices for flavor instead of salt
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (75f67148-77e0-44a5-9141-46b18482c5ce): Maximum turns (1) reached
# diet_manager (to doctor):
#
# Here is a 7-day sample vegetarian diet plan for weight loss with diabetes:
#
# * Eat:
# 	+ Leafy greens (spinach, kale, collard greens)
# 	+ Cruciferous vegetables (broccoli, cauliflower, bell peppers)
# 	+ Legumes (lentils, chickpeas, black beans)
# 	+ Whole grains (brown rice, quinoa, whole wheat bread)
# 	+ Nuts and seeds (almonds, chia seeds, flaxseeds)
# * Include:
# 	+ 1-2 cups of non-starchy vegetables per meal
# 	+ 1/2 cup of legumes or lentils per serving
# 	+ 1 tablespoon of healthy oil per day
# * Limit:
# 	+ Sugary drinks and desserts
# 	+ Refined grains (white rice, white bread)
# 	+ High-fat foods (cheese, butter)
# * Choose:
# 	+ Low-carb vegetables like tomatoes and cucumbers for snacks
# 	+ Herbs and spices for flavor instead of salt
#
# --------------------------------------------------------------------------------
# doctor (to diet_manager):
#
# **Dietary Safety Check:**
#
# • The diet plan appears to be well-balanced with a variety of protein sources, including legumes.
# • Adequate fiber intake is ensured through the inclusion of whole grains, nuts, and seeds.
# • Healthy fats are incorporated through the use of olive oil (assuming healthy oil = olive oil).
# • Sufficient calorie restriction for weight loss is not clearly defined.
#
# **Disclaimer:** This diet plan should not be used as a replacement for professional medical advice. Consult with your doctor or registered dietitian before making any significant changes to your diet.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ed0969a3-4b8e-4e35-adaa-72273448d6fb): Maximum turns (1) reached
#
# 🥗 Diet Plan (Nutritionist):
# Here is a 7-day sample vegetarian diet plan for weight loss with diabetes:
#
# * Eat:
# 	+ Leafy greens (spinach, kale, collard greens)
# 	+ Cruciferous vegetables (broccoli, cauliflower, bell peppers)
# 	+ Legumes (lentils, chickpeas, black beans)
# 	+ Whole grains (brown rice, quinoa, whole wheat bread)
# 	+ Nuts and seeds (almonds, chia seeds, flaxseeds)
# * Include:
# 	+ 1-2 cups of non-starchy vegetables per meal
# 	+ 1/2 cup of legumes or lentils per serving
# 	+ 1 tablespoon of healthy oil per day
# * Limit:
# 	+ Sugary drinks and desserts
# 	+ Refined grains (white rice, white bread)
# 	+ High-fat foods (cheese, butter)
# * Choose:
# 	+ Low-carb vegetables like tomatoes and cucumbers for snacks
# 	+ Herbs and spices for flavor instead of salt
#
# 🩺 Health Review (Doctor):
# **Dietary Safety Check:**
#
# • The diet plan appears to be well-balanced with a variety of protein sources, including legumes.
# • Adequate fiber intake is ensured through the inclusion of whole grains, nuts, and seeds.
# • Healthy fats are incorporated through the use of olive oil (assuming healthy oil = olive oil).
# • Sufficient calorie restriction for weight loss is not clearly defined.
#
# **Disclaimer:** This diet plan should not be used as a replacement for professional medical advice. Consult with your doctor or registered dietitian before making any significant changes to your diet.
